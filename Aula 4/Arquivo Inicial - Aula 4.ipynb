# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
#
# - Base de Dados: https://drive.google.com/drive/folders/1o2lpxoi9heyQV1hIlsHXWSfDkBPtze-V?usp=sharing

# %% [markdown]
# ### Passo a Passo de um Projeto de Ciência de Dados
#
# - Passo 1: Entendimento do Desafio
# - Passo 2: Entendimento da Área/Empresa
# - Passo 3: Extração/Obtenção de Dados
# - Passo 4: Ajuste de Dados (Tratamento/Limpeza)
# - Passo 5: Análise Exploratória
# - Passo 6: Modelagem + Algoritmos (Aqui que entra a Inteligência Artificial, se necessário)
# - Passo 7: Interpretação de Resultados

# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
# - TV, Jornal e Rádio estão em milhares de reais
# - Vendas estão em milhões

# %% [markdown]
# #### Importar a Base de dados

# %%
# importar a base de dados

import pandas as pd

tabela = pd.read_csv('advertising.csv')
display(tabela)
print(tabela.info())
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Radio   200 non-null    float64
#  2   Jornal  200 non-null    float64
#  3   Vendas  200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None

# %% [markdown]
# #### Análise Exploratória
# - Vamos tentar visualizar como as informações de cada item estão distribuídas
# - Vamos ver a correlação entre cada um dos itens

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in /home/sweyd/.local/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: numpy>=1.19 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: cycler>=0.10 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib) (20.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 897 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/sweyd/.local/lib/python3.9/site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: pandas>=0.25 in /home/sweyd/.local/lib/python3.9/site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/sweyd/.local/lib/python3.9/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/sweyd/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (20.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.25->seaborn) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 909 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /home/sweyd/.local/lib/python3.9/site-packages (from scikit-learn) (1.23.4)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 324 kB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      |████████████████████████████████| 34.4 MB 569 kB/s eta 0:00:01
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.0 scipy-1.10.0 threadpoolctl-3.1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print(tabela.corr())

# criar um grafico
sns.heatmap(tabela.corr(), cmap='Greens', annot=True)

# exibe o grafico
plt.show()
# Out:
#               TV     Radio    Jornal    Vendas
# TV      1.000000  0.054809  0.056648  0.901208
# Radio   0.054809  1.000000  0.354104  0.349631
# Jornal  0.056648  0.354104  1.000000  0.157960
# Vendas  0.901208  0.349631  0.157960  1.000000

# %% [markdown]
# #### Com isso, podemos partir para a preparação dos dados para treinarmos o Modelo de Machine Learning
#
# - Separando em dados de treino e dados de teste

# %%
y = tabela['Vendas']
x = tabela[['TV', 'Radio', 'Jornal']]

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)

# %% [markdown]
# #### Temos um problema de regressão - Vamos escolher os modelos que vamos usar:
#
# - Regressão Linear
# - RandomForest (Árvore de Decisão)

# %%
# importar a inteligencia artificial (modelo)
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# criar
modeloRegressaoLinear = LinearRegression()
modeloArvoreDecisao = RandomForestRegressor()

# treinar
modeloRegressaoLinear.fit(x_treino, y_treino)
modeloArvoreDecisao.fit(x_treino, y_treino)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Teste da AI e Avaliação do Melhor Modelo
#
# - Vamos usar o R² -> diz o % que o nosso modelo consegue explicar o que acontece

# %%
previsaoRegressaoLinear = modeloRegressaoLinear.predict(x_teste)
previsaoArvoreDecisao = modeloArvoreDecisao.predict(x_teste)

from sklearn.metrics import r2_score

print(r2_score(y_teste, previsaoRegressaoLinear))
print(r2_score(y_teste, previsaoArvoreDecisao))
# Out:
# 0.8831412528532008
# 0.955711926077712

# %% [markdown]
# #### Visualização Gráfica das Previsões

# %%
tabelaAuxiliar = pd.DataFrame()
tabelaAuxiliar['y_teste'] = y_teste
tabelaAuxiliar['Previsao Arvore Decisao'] = previsaoArvoreDecisao
tabelaAuxiliar['Previsao Regressao Linear'] = previsaoRegressaoLinear

sns.lineplot(data=tabelaAuxiliar)
plt.show()

# %% [markdown]
# #### Como fazer uma nova previsão?

# %%
novaTabela = pd.read_csv('novos.csv')
display(novaTabela)
# Out:
#       TV  Radio  Jornal
# 0   23.1    3.8    69.2
# 1   44.5    0.0     5.1
# 2  170.2   45.9     0.0

# %%
previsao = modeloArvoreDecisao.predict(novaTabela)

print(previsao)
# Out:
# [ 7.456  8.899 20.451]
